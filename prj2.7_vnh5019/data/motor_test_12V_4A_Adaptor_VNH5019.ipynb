# %%
import numpy as np
import pandas as pd
from scipy import interpolate
import matplotlib.pyplot as plt

# %%
def plot_graph(title, f1, f2):
    # read input file
    data1 = pd.read_csv(f1)
    data2 = pd.read_csv(f2)

    # interpolate
    f1 = interpolate.interp1d(data1.pwm, data1.RPM)
    #f1 = interpolate.interp1d(data1.PWM, data1.average_RPM, kind='cubic')
    f2 = interpolate.interp1d(data2.pwm, data2.RPM)
    x1 = np.linspace(0, 260, num=261, endpoint=True)
    x2 = np.linspace(0, 260, num=261, endpoint=True)

    # plot
    plt.plot(data1.pwm, data1.RPM, 'o', x1, f1(x1), '-', data2.pwm, data2.RPM, 'x', x2, f2(x2), '--')
    plt.xlabel('PWM')
    plt.ylabel('RPM')
    plt.grid(True)
    plt.legend(['', 'increasing', '', 'decreasing'])
    plt.title(title)
    plt.show()

# %%
# test data
data1 = pd.read_csv("12V_4A_Adaptor_VNH5019_31250Hz.1.dat")
data1
# Out:
#     pwm  intr  RPM    speed
# 0     0     0    0     0.00
# 1    10     0    0     0.00
# 2    20     0    0     0.00
# 3    30     0    0     0.00
# 4    40   469   85   548.04
# 5    50   547   99   638.37
# 6    60   610  110   729.86
# 7    70   674  122   729.86
# 8    80   739  134   821.41
# 9    90   809  146   911.24
# 10  100   875  158  1003.95
# 11  110   941  170  1004.35
# 12  120  1008  182  1095.22
# 13  130  1083  196  1276.74
# 14  140  1157  210  1370.10
# 15  150  1229  222  1370.10
# 16  160  1298  235  1459.71
# 17  170  1366  248  1551.56
# 18  180  1427  259  1641.53
# 19  190  1483  269  1642.82
# 20  200  1536  278  1734.09
# 21  210  1581  287  1733.41
# 22  220  1617  293  1826.80
# 23  230  1643  297  1824.64
# 24  240  1660  301  1826.08
# 25  250  1663  301  1823.20
# 26  260  1663  301  1912.10

# %%
data1.columns
# Out:
# Index([u'pwm', u'intr', u'RPM', u'speed'], dtype='object')

# %%
plot_graph('12V_4A_Adaptor_VNH5019_31250Hz', "12V_4A_Adaptor_VNH5019_31250Hz.1.dat", "12V_4A_Adaptor_VNH5019_31250Hz.2.dat")
