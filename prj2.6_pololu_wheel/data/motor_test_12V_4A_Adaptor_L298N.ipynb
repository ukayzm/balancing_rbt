# %%
import numpy as np
import pandas as pd
from scipy import interpolate
import matplotlib.pyplot as plt

# %%
def plot_graph(title, f1, f2):
    # read input file
    data1 = pd.read_csv(f1)
    data2 = pd.read_csv(f2)

    # interpolate
    f1 = interpolate.interp1d(data1.pwm, data1.RPM)
    #f1 = interpolate.interp1d(data1.PWM, data1.average_RPM, kind='cubic')
    f2 = interpolate.interp1d(data2.pwm, data2.RPM)
    x1 = np.linspace(0, 260, num=261, endpoint=True)
    x2 = np.linspace(0, 260, num=261, endpoint=True)

    # plot
    plt.plot(data1.pwm, data1.RPM, 'o', x1, f1(x1), '-', data2.pwm, data2.RPM, 'x', x2, f2(x2), '--')
    plt.xlabel('PWM')
    plt.ylabel('RPM')
    plt.grid(True)
    plt.legend(['', 'increasing', '', 'decreasing'])
    plt.title(title)
    plt.show()

# %%
# test data
data1 = pd.read_csv("12V_4A_Adaptor_L298N_30Hz.1.dat")
data1
# Out:
#     pwm  intr  RPM    speed
# 0     0     0    0     0.00
# 1    10    -2    0     0.00
# 2    20    22    3   -91.34
# 3    30   540   98   822.06
# 4    40   962  174  1095.65
# 5    50  1070  194  1186.95
# 6    60  1138  206  1278.26
# 7    70  1187  215  1370.10
# 8    80  1222  222  1278.26
# 9    90  1247  226  1457.41
# 10  100  1267  230  1368.48
# 11  110  1288  233  1461.44
# 12  120  1302  236  1460.87
# 13  130  1316  238  1551.56
# 14  140  1328  241  1459.71
# 15  150  1338  242  1459.71
# 16  160  1348  244  1552.78
# 17  170  1355  246  1459.71
# 18  180  1363  247  1552.17
# 19  190  1371  248  1552.78
# 20  200  1377  250  1550.94
# 21  210  1385  251  1549.72
# 22  220  1391  252  1641.53
# 23  230  1397  253  1642.18
# 24  240  1402  254  1549.72
# 25  250  1408  255  1552.17
# 26  260  1413  256  1638.94

# %%
data1.columns
# Out:
# Index([u'pwm', u'intr', u'RPM', u'speed'], dtype='object')

# %%
plot_graph('12V_4A_Adaptor_L298N_30Hz', "12V_4A_Adaptor_L298N_30Hz.1.dat", "12V_4A_Adaptor_L298N_30Hz.2.dat")

# %%
plot_graph('12V_4A_Adaptor_L298N_122Hz', "12V_4A_Adaptor_L298N_122Hz.1.dat", "12V_4A_Adaptor_L298N_122Hz.2.dat")

# %%
plot_graph('12V_4A_Adaptor_L298N_488Hz', "12V_4A_Adaptor_L298N_488Hz.1.dat", "12V_4A_Adaptor_L298N_488Hz.2.dat")

# %%
plot_graph('12V_4A_Adaptor_L298N_3906Hz', "12V_4A_Adaptor_L298N_3906Hz.1.dat", "12V_4A_Adaptor_L298N_3906Hz.2.dat")

# %%
plot_graph('12V_4A_Adaptor_L298N_31250Hz', "12V_4A_Adaptor_L298N_31250Hz.1.dat", "12V_4A_Adaptor_L298N_31250Hz.2.dat")
