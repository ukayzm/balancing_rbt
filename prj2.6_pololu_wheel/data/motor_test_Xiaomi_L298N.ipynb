# %%
import numpy as np
import pandas as pd
from scipy import interpolate
import matplotlib.pyplot as plt

# %%
def plot_graph(title, f1, f2):
    # read input file
    data1 = pd.read_csv(f1)
    data2 = pd.read_csv(f2)

    # interpolate
    f1 = interpolate.interp1d(data1.pwm, data1.RPM)
    #f1 = interpolate.interp1d(data1.PWM, data1.average_RPM, kind='cubic')
    f2 = interpolate.interp1d(data2.pwm, data2.RPM)
    x1 = np.linspace(0, 260, num=261, endpoint=True)
    x2 = np.linspace(0, 260, num=261, endpoint=True)

    # plot
    plt.plot(data1.pwm, data1.RPM, 'o', x1, f1(x1), '-', data2.pwm, data2.RPM, 'x', x2, f2(x2), '--')
    plt.xlabel('PWM')
    plt.ylabel('RPM')
    plt.grid(True)
    plt.legend(['', 'increasing', '', 'decreasing'])
    plt.title(title)
    plt.show()

# %%
# test data
data1 = pd.read_csv("Xiaomi_L298N_30Hz.1.dat")
data1
# Out:
#     pwm  intr  RPM    speed
# 0     0     0    0     0.00
# 1    10    -1    0     0.00
# 2    20     2    0   -91.20
# 3    30    23    4   -91.99
# 4    40   216   39   547.82
# 5    50   871  158  1096.08
# 6    60  1044  189  1187.42
# 7    70  1127  204  1276.74
# 8    80  1171  212  1369.02
# 9    90  1199  217  1366.86
# 10  100  1227  222  1368.48
# 11  110  1248  226  1368.48
# 12  120  1265  229  1461.44
# 13  130  1276  231  1369.56
# 14  140  1282  232  1459.71
# 15  150  1293  234  1459.14
# 16  160  1301  236  1460.29
# 17  170  1311  237  1548.50
# 18  180  1318  239  1459.14
# 19  190  1324  240  1549.72
# 20  200  1332  241  1549.11
# 21  210  1338  242  1549.11
# 22  220  1345  244  1550.94
# 23  230  1349  244  1550.94
# 24  240  1355  246  1459.71
# 25  250  1360  246  1549.72
# 26  260  1365  247  1551.56

# %%
data1.columns
# Out:
# Index([u'pwm', u'intr', u'RPM', u'speed'], dtype='object')

# %%
plot_graph('Xiaomi_L298N_30Hz', "Xiaomi_L298N_30Hz.1.dat", "Xiaomi_L298N_30Hz.2.dat")

# %%
plot_graph('Xiaomi_L298N_122Hz', "Xiaomi_L298N_122Hz.1.dat", "Xiaomi_L298N_122Hz.2.dat")

# %%
plot_graph('Xiaomi_L298N_488Hz', "Xiaomi_L298N_488Hz.1.dat", "Xiaomi_L298N_488Hz.2.dat")

# %%
plot_graph('Xiaomi_L298N_3906Hz', "Xiaomi_L298N_3906Hz.1.dat", "Xiaomi_L298N_3906Hz.2.dat")

# %%
plot_graph('Xiaomi_L298N_31250Hz', "Xiaomi_L298N_31250Hz.1.dat", "Xiaomi_L298N_31250Hz.2.dat")
